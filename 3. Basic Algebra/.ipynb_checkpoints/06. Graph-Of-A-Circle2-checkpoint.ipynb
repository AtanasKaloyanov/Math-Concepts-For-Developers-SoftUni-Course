# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# radius
r = 1
phi = np.linspace(0, 2 * np.pi, 1000)

x = r * np.cos(phi)
y = r * np.sin(phi)
plt.plot(x, y)
plt.gca().set_aspect("equal")
plt.show()
