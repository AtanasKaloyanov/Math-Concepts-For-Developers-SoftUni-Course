# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def throw_dice():
    return np.random.randint( 1 , 7 )
   
x = [throw_dice() for i in range(100)]
plt.plot(x)
plt.show()

throw_dice()
# Out:
# 3
