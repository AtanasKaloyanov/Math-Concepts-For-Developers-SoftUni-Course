# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#     x^2 + y^2 = 1 
def circle_graph(f, start, end, count):
    x = np.linspace(start, end, count)
    y = f(x)
    
    ax = plt.gca()
    
    ax.spines["left"].set_position("zero")
    ax.spines["bottom"].set_position("zero")
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    
    ax.set_aspect("equal")
    
    plt.plot(x, y)

# %%
circle_graph(lambda x: np.sqrt(1 - x ** 2), -3, 3, 1000)
circle_graph(lambda x: -np.sqrt(1 - x ** 2), -3, 3, 1000)
plt.show()
# Out:
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_14560\3433822117.py:1: RuntimeWarning: invalid value encountered in sqrt
#   circle_graph(lambda x: np.sqrt(1 - x ** 2), -3, 3, 1000)
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_14560\3433822117.py:2: RuntimeWarning: invalid value encountered in sqrt
#   circle_graph(lambda x: -np.sqrt(1 - x ** 2), -3, 3, 1000)
